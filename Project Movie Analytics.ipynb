# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd # -> Module yang digunaakn untuk analisis data, editing dataframe

# %%
import numpy as np # -> Module yang digunakan untuk operasi matematika

# %%
import matplotlib.pyplot as plt # -> Module yang digunakan untuk melakukan visualisasi data

# %%
import seaborn as sns # -> Module yang digunakan untuk melakukan visualisasi data

# %%
import os # -> Untuk melakukan operasi sistem di google colab

# %%
os.chdir("/content/gdrive/MyDrive/Materi Mentoring/Movie Analytics")

# %%
os.listdir()
# Out:
# ['Movie Analytics.ipynb', 'ratings_small.csv', 'movies_metadata.csv']

# %%
movies_data = pd.read_csv("movies_metadata.csv")

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
#  14  release_date           45376 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 7.7+ MB

# %%
movies_data.sample(10)
# Out:
#        adult                              belongs_to_collection     budget  \
# 37474   True                                                NaN          0
# 14750   True                                                NaN          0
# 1880    True  {'id': 123255, 'name': 'Prom Night Collection'...          0
# 18249   True                                                NaN          0
# 27259   True                                                NaN          0
# 18511   True                                                NaN          0
# 17921   True                                                NaN          0
# 22359   True                                                NaN   32000000
# 10554   True  {'id': 1241, 'name': 'Harry Potter Collection'...  150000000
# 11952   True                                                NaN          0
#
#                                                   genres  \
# 37474                      [{'id': 18, 'name': 'Drama'}]
# 14750                     [{'id': 35, 'name': 'Comedy'}]
# 1880   [{'id': 53, 'name': 'Thriller'}, {'id': 35, 'n...
# 18249  [{'id': 10402, 'name': 'Music'}, {'id': 18, 'n...
# 27259                      [{'id': 18, 'name': 'Drama'}]
# 18511  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 17921                     [{'id': 35, 'name': 'Comedy'}]
# 22359  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...
# 10554  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 11952  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                  homepage      id    imdb_id  \
# 37474                                 NaN   50268  tt0092720
# 14750                                 NaN   48609  tt0091051
# 1880                                  NaN   41828  tt0098136
# 18249                                 NaN   77381  tt0060543
# 27259                                 NaN   52857  tt0048512
# 18511                                 NaN   42457  tt0069987
# 17921                                 NaN   83015  tt0042541
# 22359                                 NaN  169881  tt2101473
# 10554  http://harrypotter.warnerbros.com/     674  tt0330373
# 11952                                 NaN   32444  tt0398963
#
#       original_language                       original_title  \
# 37474                it                            Capriccio
# 14750                en                          A Fine Mess
# 1880                 en        Prom Night III: The Last Kiss
# 18249                cs                    Intimní osvětlení
# 27259                en                         The Prisoner
# 18511                en                       A Doll's House
# 17921                en       The Happiest Days of Your Life
# 22359                en                        The Physician
# 10554                en  Harry Potter and the Goblet of Fire
# 11952                en                         Dorian Blues
#
#                                                 overview  ...  release_date  \
# 37474  After the renewed flings with their former lov...  ...    1987-02-25
# 14750  Two friends an actor and a chef discover a plo...  ...    1986-08-08
# 1880   Mary Lou, the prom queen burned to death by he...  ...    1990-03-30
# 18249  Taking his young city girlfriend along for the...  ...    1965-04-08
# 27259  A cardinal is arrested for treason against the...  ...    1955-04-19
# 18511  Nora Helmer has years earlier committed a forg...  ...    1973-05-22
# 17921  Nutbourne College, an old established, all-boy...  ...    1950-01-01
# 22359  The story of Rob Cole, a boy who is left a pen...  ...    2013-12-25
# 10554  Harry starts his fourth year at Hogwarts, comp...  ...    2005-11-05
# 11952  Dorian realizes he is gay in his final year of...  ...    2004-01-01
#
#            revenue runtime                                   spoken_languages  \
# 37474          0.0    98.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 14750    6029824.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1880           0.0    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18249          0.0    71.0             [{'iso_639_1': 'cs', 'name': 'Český'}]
# 27259          0.0    95.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18511          0.0   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 17921          0.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 22359   57284237.0   155.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 10554  895921036.0   157.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 11952          0.0    88.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 37474  Released                                                NaN
# 14750  Released                             A Hilarious New Comedy
# 1880   Released                        A Romantic Comedy from Hell
# 18249  Released                                                NaN
# 27259  Released                                                NaN
# 18511  Released  He is the master. He's called a husband. She i...
# 17921  Released                                                NaN
# 22359  Released                                                NaN
# 10554  Released                Dark And Difficult Times Lie Ahead.
# 11952  Released                                                NaN
#
#                                      title  video vote_average vote_count
# 37474                       Love & Passion  False          3.9        9.0
# 14750                          A Fine Mess  False          3.4        5.0
# 1880         Prom Night III: The Last Kiss  False          5.1       15.0
# 18249                    Intimate Lighting  False          6.5        4.0
# 27259                         The Prisoner  False          7.1        4.0
# 18511                       A Doll's House  False          5.6        8.0
# 17921       The Happiest Days of Your Life  False          5.9       10.0
# 22359                        The Physician  False          7.2      365.0
# 10554  Harry Potter and the Goblet of Fire  False          7.5     5758.0
# 11952                         Dorian Blues  False          6.3        8.0
#
# [10 rows x 24 columns]

# %%
movies_data["release_date"] = pd.to_datetime(movies_data["release_date"])

# %%
movies_data["release_date"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
movies_data["status"].unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
movies_data["original_language"].nunique()
# Out:
# 89

# %%
movies_data["status"] == "Released"
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 45458    True
# 45459    True
# 45460    True
# 45461    True
# 45462    True
# Name: status, Length: 45463, dtype: bool

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
#  14  release_date           45376 non-null  datetime64[ns]
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(5), int64(2), object(14)
# memory usage: 7.7+ MB

# %%
movies_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
movies_data["profit"] = movies_data["revenue"] - movies_data["budget"]

# %%
movies_data["profit"].hist(bins = 100)
# Out:
# <Axes: >

# %%
plt.title("Profit Movies Distribution")
# Out:
# Text(0.5, 1.0, 'Profit Movies Distribution')

# %%
plt.show()

# %%
movies_data["profit"].describe()
# Out:
# count    4.546000e+04
# mean     6.984491e+06
# std      5.214125e+07
# min     -1.657101e+08
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.550965e+09
# Name: profit, dtype: float64

# %%
import seaborn as sns

# %%
movies_data["profit"].plot(kind = "box")
# Out:
# <Axes: >

# %%
sns.boxplot(data = movies_data, x = "profit")
# Out:
# <Axes: xlabel='profit'>

# %%
plt.show()

# %%
sns.boxplot(data = movies_data, x = "runtime")
# Out:
# <Axes: xlabel='runtime'>

# %%
plt.show()

# %%
movies_data["profit"].quantile(0.9)
# Out:
# 1578210.8999999824

# %%
sns.scatterplot(data = movies_data,
                x = "runtime",
                y = "profit")
# Out:
# <Axes: xlabel='runtime', ylabel='profit'>

# %%
plt.show()

# %%
profitable_movies = movies_data[movies_data["profit"] > 0]

# %%
sns.scatterplot(data = profitable_movies, x = "runtime", y = "profit")
# Out:
# <Axes: xlabel='runtime', ylabel='profit'>

# %%
plt.show()

# %%
rating = pd.read_csv("ratings_small.csv")

# %%
rating_movies = rating.groupby("movieId", as_index = False)["rating"].median()

# %%
sns.histplot(data = rating_movies, x = "rating")
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
rating_movies["good_movies"] = rating_movies["rating"] >= 3

# %%
rating_movies["good_movies"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
new_df = movies_data.merge(rating_movies, left_on = "id", right_on = "movieId", how = "inner")

# %%
sns.histplot(data = new_df,  x = "profit", hue = "good_movies")
# Out:
# <Axes: xlabel='profit', ylabel='Count'>

# %%
sns.scatterplot(data = new_df, x = "rating", y = "profit")
# Out:
# <Axes: xlabel='rating', ylabel='profit'>

# %%
new_df[["rating"]]
# Out:
#       rating
# 0       3.75
# 1       1.50
# 2       4.00
# 3       3.50
# 4       5.00
# ...      ...
# 2826    3.25
# 2827    4.00
# 2828    4.00
# 2829    4.00
# 2830    5.00
#
# [2831 rows x 1 columns]

# %%
new_df["original_language"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='original_language'>

# %%
new_df.select_dtypes(include = "number")
# Out:
#         budget     id  popularity      revenue  runtime  vote_average  \
# 0     60000000    949   17.924927  187436818.0    170.0           7.7
# 1     58000000    710   14.686036  352194034.0    130.0           6.6
# 2     98000000   1408    7.284477   10017322.0    119.0           5.7
# 3     52000000    524   10.137389  116112375.0    178.0           7.8
# 4     16500000   4584   10.673167  135000000.0    136.0           7.2
# ...        ...    ...         ...          ...      ...           ...
# 2826         0  80831    0.083371          0.0    121.0           6.5
# 2827         0   3104    2.302582          0.0     92.0           5.9
# 2828         0  64197    0.528657          0.0     97.0           6.0
# 2829         0  98604    0.803588          0.0     91.0           4.6
# 2830         0  49280    1.109068          0.0      1.0           6.5
#
#       vote_count       profit  movieId  rating
# 0         1886.0  127436818.0      949    3.75
# 1         1194.0  294194034.0      710    1.50
# 2          137.0  -87982678.0     1408    4.00
# 3         1343.0   64112375.0      524    3.50
# 4          364.0  118500000.0     4584    5.00
# ...          ...          ...      ...     ...
# 2826         2.0          0.0    80831    3.25
# 2827        33.0          0.0     3104    4.00
# 2828         5.0          0.0    64197    4.00
# 2829         6.0          0.0    98604    4.00
# 2830        22.0          0.0    49280    5.00
#
# [2831 rows x 10 columns]

# %%
def select_columns(df: pd.DataFrame, features: list,  target: list = "rating"):

  df = df.dropna().reset_index(drop = True)
  X = df[features]
  y = (df[target] >= 3).astype("int")

  return X, y

# %%
from sklearn.model_selection import train_test_split

# %%
features = ["budget", "popularity", "vote_average"]

# %%
X, y = select_columns(new_df, features = features)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
minmax.fit(X_train)
# Out:
# MinMaxScaler()

# %%
def scaling(df, scaler):

  # df["runtime	"] = df["runtime"].div(60)

  scaled_array = scaler.transform(df)
  scaled_df = pd.DataFrame(scaled_array, columns = scaler.get_feature_names_out())

  return scaled_df

# %%
X_train_scaled = scaling(X_train, minmax)

# %%
X_test_scaled = scaling(X_test, minmax)

# %%
X_test_scaled.iloc[0]
# Out:
# budget          0.500000
# popularity      0.042270
# vote_average    0.568182
# Name: 0, dtype: float64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5)

# %%
dt = DecisionTreeClassifier()

# %%
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
dt.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred_knn = knn.predict(X_train_scaled)

# %%
y_train_pred_dt = dt.predict(X_train_scaled)

# %%
y_test_pred_knn = knn.predict(X_test_scaled)

# %%
y_test_pred_dt = dt.predict(X_test_scaled)

# %%
pd.crosstab(y_test, y_test_pred_knn)
# Out:
# col_0   0   1
# rating
# 0       0   6
# 1       1  35

# %%
pd.crosstab(y_test, y_test_pred_dt)
# Out:
# col_0   0   1
# rating
# 0       0   6
# 1       5  31
